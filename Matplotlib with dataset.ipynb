# %% [markdown]
# # Support Vector Machine (SVM)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Placement_Data_Full_Class.csv')

# %%
# Number of rows and Columns 
print("The Number of Row:",dataset.shape[0])
print("The Number of Column",dataset.shape[1])
# Out:
# The Number of Row: 215
# The Number of Column 15

# %%
# Load the user defined function
from Descriptive import Descriptive
obj=Descriptive()

# %%
#Split Quantative and Qualtative column names
quantative,qualtative=obj.segreQuanQual(dataset)
# Out:
# The Quantitative Data: ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# The Qualtitative Data ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
#Descriptive Porcess
des_Data=obj.descriptive_Analysis(dataset,quantative)
des_Data
# Out:
#              sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Count          215        215        215        215        215        215
# Mean         108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median       108.0       67.0       65.0       66.0       71.0       62.0
# Mode             1       62.0       63.0       65.0       60.0       56.7
# Std      62.209324  10.827205  10.897509   7.358743  13.275956   5.833385
# Min            1.0      40.89       37.0       50.0       50.0      51.21
# Q1:25%        54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%       108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%       161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%      215.0       89.4       97.7       91.0       98.0      77.89
# IQR          107.0       15.1       12.1       11.0       23.5       8.31
# 1.5Rule      160.5      22.65      18.15       16.5      35.25     12.465
# Lesser      -106.0      37.95      42.75       44.5      24.75      45.48
# Greater      322.0      98.35      91.15       88.5     118.75      78.72
#
#                 salary
# Count              215
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Std        93457.45242
# Min           200000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       940000.0
# IQR            60000.0
# 1.5Rule        90000.0
# Lesser        150000.0
# Greater       390000.0

# %%
#Checking the outlier
lesser,greater=obj.outliercolumn(quantative,des_Data)
# Out:
# Lesser Range ['hsc_p']
# Greater Range ['hsc_p', 'degree_p', 'salary']

# %%
# to remove warning message
import warnings
warnings.filterwarnings('ignore')

# %%
# if outlier present run this, to replace the value
change_Data=obj.changeoutlier(dataset,des_Data,lesser,greater)
change_Data
# Out:
#              sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Count          215        215        215        215        215        215
# Mean         108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median       108.0       67.0       65.0       66.0       71.0       62.0
# Mode             1       62.0       63.0       65.0       60.0       56.7
# Std      62.209324  10.827205  10.897509   7.358743  13.275956   5.833385
# Min            1.0      40.89       37.0       50.0       50.0      51.21
# Q1:25%        54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%       108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%       161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%      215.0       89.4       97.7       91.0       98.0      77.89
# IQR          107.0       15.1       12.1       11.0       23.5       8.31
# 1.5Rule      160.5      22.65      18.15       16.5      35.25     12.465
# Lesser      -106.0      37.95      42.75       44.5      24.75      45.48
# Greater      322.0      98.35      91.15       88.5     118.75      78.72
#
#                 salary
# Count              215
# Mean     288655.405405
# Median        265000.0
# Mode          300000.0
# Std        93457.45242
# Min           200000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       940000.0
# IQR            60000.0
# 1.5Rule        90000.0
# Lesser        150000.0
# Greater       390000.0

# %%
# After replacement of outlier we are checking with Descriptive analysis
des_Data=obj.descriptive_Analysis(dataset,quantative)
des_Data
# Out:
#              sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Count          215        215        215        215        215        215
# Mean         108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median       108.0       67.0       65.0       66.0       71.0       62.0
# Mode             1       62.0       63.0       65.0       60.0       56.7
# Std      62.209324  10.827205  10.586016   7.321524  13.275956   5.833385
# Min            1.0      40.89      42.75       50.0       50.0      51.21
# Q1:25%        54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50%       108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75%       161.5       75.7       73.0       72.0       83.5     66.255
# Q4:100%      215.0       89.4      91.15       88.5       98.0      77.89
# IQR          107.0       15.1       12.1       11.0       23.5       8.31
# 1.5Rule      160.5      22.65      18.15       16.5      35.25     12.465
# Lesser      -106.0      37.95      42.75       44.5      24.75      45.48
# Greater      322.0      98.35      91.15       88.5     118.75      78.72
#
#                 salary
# Count              215
# Mean     277648.648649
# Median        265000.0
# Mode          300000.0
# Std       54264.139179
# Min           200000.0
# Q1:25%        240000.0
# Q2:50%        265000.0
# Q3:75%        300000.0
# Q4:100%       390000.0
# IQR            60000.0
# 1.5Rule        90000.0
# Lesser        150000.0
# Greater       390000.0

# %%
#Cross Checking
lesser,greater=obj.outliercolumn(quantative,des_Data)
# Out:
# Lesser Range []
# Greater Range []

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
X1=dataset['ssc_p']
Y1=dataset['hsc_p']

# %% [markdown]
# ### plot

# %%
plt.plot(X1, marker='o',color='red',linestyle='dashed',
...      linewidth=1, markersize=3)
#plt.plot([1, 2, 3, 4], [1, 2, 3, 4],marker='o',color='BLUE',linestyle='dashed',
...      #linewidth=2, markersize=12)
plt.grid(True)#default
plt.grid(color='b', ls = '-.', lw = 1)
plt.title("Line plot",loc="center")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
# Out:
# Text(0, 0.5, 'y-axis')

# %%
X, Y = np.meshgrid(X1, Y1)
#Z = np.sqrt(X**2 + Y**2)
Z=X-Y
cp=plt.contour(X, Y, Z)
plt.grid(True)#default
plt.grid(color='b', ls = '-.', lw = 1)
plt.title("Line plot",loc="right")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.colorbar(cp)
plt.show()

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

X, Y = np.meshgrid(X1, Y1)
Z = np.sqrt(X**2 + Y**2)
cp=plt.contourf(X, Y, Z)
#ax.contour3D(X, Y, Z, 50, cmap='gray')
ax.plot_wireframe(X, Y, Z, color='black')
#ax.plot_surface(X,Y,Z,cmap='viridis', edgecolor='none')
plt.show()

# %%
plt.boxplot([X1,Y1])
plt.show()

# %%
plt.violinplot([X1,Y1])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x21b83bc7ed0>,
#   <matplotlib.collections.PolyCollection at 0x21b85d85010>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x21b800183d0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x21b85d87a50>,
#  'cbars': <matplotlib.collections.LineCollection at 0x21bf27731d0>}
